# %% [markdown]
# ## Game Altering Plays
# Sean Steinle
#
# 1. [Introduction](#1)
# 2. [Trimming the DF](#2)
# 3. [Return Positive Plays](#3)
# 4. [Kick Positive Plays](#4)
#
# <a id='1'>

# %% [markdown]
# ### Introduction

# %% [markdown]
# In determining the value of kickoff returns for the returning team, there are plays that shift field position and there are plays that alter the game. In this notebook, we'll take a deep dive into the latter.
#
# The metrics we'll consider in this notebook are muffs (*isMuff*, *retainsMuff*), fumbles (*isFumble*, *retainsFumble*), and touchdowns (*isTouchdown*). We'll also cut down the dataframe of kickoffs to relevant kickoffs.

# %% [markdown]
# ### Trimming the DF

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk

# %%
df = pd.read_csv("kickoff_dataset.csv")
df
# Out:
#        Unnamed: 0 kicking_team receiving_team  year  \
# 0               5          PIT            TEN  2009
# 1              15          MIN            CLE  2009
# 2              45          NYJ            HOU  2009
# 3              47          NYJ            HOU  2009
# 4              48          HOU            NYJ  2009
# ...           ...          ...            ...   ...
# 28310       28310          SEA             SF  2019
# 28311       28311           SF            SEA  2019
# 28312       28312          SEA             SF  2019
# 28313       28313           SF            SEA  2019
# 28314       28314          SEA             SF  2019
#
#                                                     text        kicker  \
# 0      J.Reed kicks 61 yards from PIT 30 to TEN 9. J....        J.Reed
# 1      R.Longwell kicks 66 yards from MIN 30 to CLE 4...    R.Longwell
# 2      J.Feely kicks 72 yards from NYJ 30 to HOU -2. ...       J.Feely
# 3      J.Feely kicks 71 yards from NYJ 30 to HOU -1. ...       J.Feely
# 4      K.Brown kicks 67 yards from HOU 30 to NYJ 3. L...       K.Brown
# ...                                                  ...           ...
# 28310  J.Myers kicks 65 yards from SEA 35 to end zone...       J.Myers
# 28311  M.Wishnowsky kicks 65 yards from SF 35 to end ...  M.Wishnowsky
# 28312  J.Myers kicks 65 yards from SEA 35 to end zone...       J.Myers
# 28313  M.Wishnowsky kicks 43 yards from SF 35 to SEA ...  M.Wishnowsky
# 28314  J.Myers kicks 44 yards from SEA 35 to SF 21. R...       J.Myers
#
#        isTouchback  isOutOfBounds  isOnside  isFairCatch  ...  isMuff  \
# 0            False          False     False        False  ...   False
# 1            False          False     False        False  ...   False
# 2            False          False     False        False  ...   False
# 3            False          False     False        False  ...   False
# 4            False          False     False        False  ...   False
# ...            ...            ...       ...          ...  ...     ...
# 28310         True          False     False        False  ...   False
# 28311         True          False     False        False  ...   False
# 28312         True          False     False        False  ...   False
# 28313        False           True     False        False  ...   False
# 28314        False          False     False        False  ...    True
#
#        retainsMuff  isPenalty penalizedPlayer penaltyYards  \
# 0             True       True        G.McRath           10
# 1             True       True        K.Maiava           10
# 2             True       True      C.Thompson           10
# 3             True       True      C.Thompson           10
# 4             True       True     J.Westerman           10
# ...            ...        ...             ...          ...
# 28310         True      False       no player            0
# 28311         True      False       no player            0
# 28312         True      False       no player            0
# 28313         True      False       no player            0
# 28314         True      False       no player            0
#
#                  penaltyType  penaltySpot  isFumble  retainsFumble  finalSpot
# 0          Offensive Holding           72     False           True         82
# 1          Offensive Holding           71     False           True         81
# 2          Offensive Holding           70     False           True         80
# 3      Unnecessary Roughness           80     False           True         90
# 4          Offensive Holding           77     False           True         87
# ...                      ...          ...       ...            ...        ...
# 28310             no penalty            0     False           True        100
# 28311             no penalty            0     False           True        100
# 28312             no penalty            0     False           True        100
# 28313             no penalty            0     False           True         78
# 28314             no penalty            0     False           True         79
#
# [28315 rows x 30 columns]

# %%
#isTouchback, isOutOfBounds, isOnside, isFairCatch, isReturned, isTouchdown, isMuff, retainsMuff, isPenalty, isFumble, retainsFumble
touchback = len(df[df["isTouchback"]])/len(df)
print(f"{touchback*100}% of kicks were touchbacks.")

oob = len(df[df["isOutOfBounds"]])/len(df)
print(f"{oob*100}% of kicks were out of bounds.")

fc = len(df[df["isFairCatch"]])/len(df)
print(f"{fc*100}% of kicks were fair catches.")

returned = len(df[df["isReturned"]])/len(df)
print(f"{returned*100}% of kicks were returned.")

td = len(df[df["isTouchdown"]])/len(df)
print(f"{td*100}% of kicks were returned for a touchdown.")

muff = len(df[df["isMuff"]])/len(df)
print(f"{muff*100}% of kicks were muffed.")

cut = df[df[""]]
rm = len(cut[cut["retainsMuff"]])/len(cut)
print(f"{rm*100}% of isMuffmuffs were retained.")

penalty = len(df[df["isPenalty"]])/len(df)
print(f"{penalty*100}% of kickoffs had an accepted penalty.")

fumble = len(df[df["isFumble"]])/len(df)
print(f"{fumble*100}% of kicks were fumbled.")

cut = df[df["isFumble"]]
rf = len(cut[cut["retainsFumble"]])/len(cut)
print(f"{rf*100}% of fumbles were retained.")

#These numbers look to be about right. One immediate comparison we can do is fumbles lost and muffs kicks vs. touchdowns.
# Out:
# 46.40649832244394% of kicks were touchbacks.
# 1.161928306551298% of kicks were out of bounds.
# 0.1553946671375596% of kicks were fair catches.
# 51.66166342927777% of kicks were returned.
# 0.42733533462828893% of kicks were returned for a touchdown.
# 0.8935193360409677% of kicks were muffed.
# 90.11857707509881% of muffs were retained.
# 4.043793042556949% of kickoffs had an accepted penalty.
# 1.0665724880805227% of kicks were fumbled.
# 46.35761589403973% of fumbles were retained.

# %%
df = df[df["isReturned"]]
len(df)
# Out:
# 14594

# %%
muff = len(df[df["isMuff"]])/len(df)
print(f"{muff*100}% of kicks were muffed.")
cut = df[df["isMuff"]]
rm = len(cut[cut["retainsMuff"]])/len(cut)
print(f"{rm*100}% of muffs were retained.")
muff_loss = (muff*100)*(1-rm)
print(f"{muff_loss}% of returned kicks were muffed and lost.")

fumble = len(df[df["isFumble"]])/len(df)
print(f"{fumble*100}% of kicks were fumbled.")
cut = df[df["isFumble"]]
rf = len(cut[cut["retainsFumble"]])/len(cut)
print(f"{rf*100}% of fumbles were retained.")
fumble_loss = (fumble*100)*(1-rf)
print(f"{fumble_loss}% of returned kicks were fumbled and lost")

print(f"{muff_loss + fumble_loss}% of returned kicks were lost due to fumble or a muffed catch.")

td = len(df[df["isTouchdown"]])/len(df)
print(f"{td*100}% of kicks were returned for a touchdown.") #WHO SCORED THE TOUCHDOWN?
#you need to figure out how
list(df[df["isTouchdown"]]["text"])
# Out:
# 1.4526517747019323% of kicks were muffed.
# 92.45283018867924% of muffs were retained.
# 0.1096340962039194% of returned kicks were muffed and lost.
# 1.8432232424283952% of kicks were fumbled.
# 40.89219330855018% of fumbles were retained.
# 1.0894888310264492% of returned kicks were fumbled and lost
# 1.1991229272303685% of returned kicks were lost due to fumble or a muffed catch.
# 0.8222557215293956% of kicks were returned for a touchdown.
# ['J.Nedney kicks 71 yards from SF 30 to MIN -1. P.Harvin for 101 yards, TOUCHDOWN.',
#  'J.Hanson kicks 72 yards from DET 30 to CHI -2. J.Knox for 102 yards, TOUCHDOWN.',
#  'S.Lechler kicks 75 yards from OAK 20 to HOU 5. J.Jones for 95 yards, TOUCHDOWN.',
#  'J.Reed kicks 68 yards from PIT 30 to CLE 2. J.Cribbs for 98 yards, TOUCHDOWN.',
#  'R.Lloyd kicks 67 yards from CAR 30 to TB 3. S.Stroughter for 97 yards, TOUCHDOWN.',
#  'N.Kaeding kicks 63 yards from SD 30 to DEN 7. E.Royal for 93 yards, TOUCHDOWN.',
#  'J.Reed kicks 58 yards from PIT 30 to MIN 12. P.Harvin for 88 yards, TOUCHDOWN. Back judge Rich Reels injured on the play.',
#  'M.Prater kicks 65 yards from DEN 30 to BAL 5. L.Webb for 95 yards, TOUCHDOWN.',
#  'J.Feely kicks 70 yards from NYJ 30 to MIA 0. T.Ginn for 100 yards, TOUCHDOWN.',
#  'J.Feely kicks 71 yards from NYJ 30 to MIA -1. T.Ginn for 101 yards, TOUCHDOWN.',
#  'Josh.Brown kicks 67 yards from STL 30 to NO 3. C.Roby for 97 yards, TOUCHDOWN.',
#  'J.Reed kicks 66 yards from PIT 30 to CIN 4. B.Scott for 96 yards, TOUCHDOWN.',
#  'J.Reed kicks 67 yards from PIT 30 to KC 3. J.Charles for 97 yards, TOUCHDOWN.',
#  'R.Bironas kicks 69 yards from TEN 30 to ARI 1. L.Stephens-Howling for 99 yards, TOUCHDOWN.',
#  'J.Scobee kicks 63 yards from JAC 30 to IND 7. C.Simpson for 93 yards, TOUCHDOWN.',
#  'R.Succop kicks 70 yards from KC 30 to CLE 0. J.Cribbs for 100 yards, TOUCHDOWN.',
#  'R.Succop kicks 73 yards from KC 30 to CLE -3. J.Cribbs for 103 yards, TOUCHDOWN.',
#  'P.McAfee kicks 76 yards from IND 30 to NYJ -6. B.Smith for 106 yards, TOUCHDOWN.',
#  'M.Nugent kicks 67 yards from CIN 30 to NE 3. B.Tate for 97 yards, TOUCHDOWN. NE 19-Tate 1st NFL TD.',
#  'R.Bironas kicks 67 yards from TEN 30 to PIT 3. M.Moore to PIT 11 for 8 yards. Handoff to A.Brown for 89 yards, TOUCHDOWN.',
#  'S.Gostkowski kicks 65 yards from NE 30 to BUF 5. C.Spiller for 95 yards, TOUCHDOWN.',
#  'S.Janikowski kicks 72 yards from OAK 30 to ARI -2. L.Stephens-Howling for 102 yards, TOUCHDOWN.',
#  'N.Kaeding kicks 71 yards from SD 30 to SEA -1. L.Washington for 101 yards, TOUCHDOWN.',
#  'N.Kaeding kicks 69 yards from SD 30 to SEA 1. L.Washington for 99 yards, TOUCHDOWN.',
#  'M.Prater kicks 68 yards from DEN 30 to TEN 2. M.Mariani for 98 yards, TOUCHDOWN.',
#  'D.Carpenter kicks 73 yards from MIA 30 to NE -3. B.Tate for 103 yards, TOUCHDOWN.',
#  'Josh.Brown kicks 75 yards from STL 30 to DET -5. S.Logan for 105 yards, TOUCHDOWN.',
#  'D.Buehler kicks 65 yards from DAL 30 to MIN 5. P.Harvin for 95 yards, TOUCHDOWN.',
#  'J.Hanson kicks 66 yards from DET 30 to WAS 4. B.Banks for 96 yards, TOUCHDOWN. Penalty on DET-C.Houston, Offside on Free Kick, declined.',
#  'R.Longwell kicks 66 yards from MIN 30 to ARI 4. L.Stephens-Howling for 96 yards, TOUCHDOWN.',
#  'J.Feely kicks 65 yards from ARI 30 to MIN 5. P.Harvin to MIN 27 for 22 yards (O.Schofield). FUMBLES (O.Schofield), RECOVERED by ARI-M.Adams at MIN 30. M.Adams for 30 yards, TOUCHDOWN. ARI-K.Iwebema was injured during the play. His return is Questionable.  Minnesota challenged the fumble ruling, and the play was Upheld. (Timeout #1 at 14:48.)',
#  'M.Koenen kicks 59 yards from ATL 30 to TB 11. M.Spurlock for 89 yards, TOUCHDOWN.',
#  'R.Succop kicks 64 yards from KC 30 to OAK 6. J.Ford for 94 yards, TOUCHDOWN. PENALTY on OAK-S.Williams, Unsportsmanlike Conduct, 15 yards, enforced between downs.',
#  'M.Crosby kicks 60 yards from GB 30 to DAL 10. B.McCann to DAL 25 for 15 yards (J.Bush). FUMBLES (J.Bush), RECOVERED by GB-N.Collins at DAL 26. N.Collins for 26 yards, TOUCHDOWN.',
#  'A.Pettrey kicks 59 yards from CIN 30 to NYJ 11. B.Smith for 89 yards, TOUCHDOWN.',
#  'D.Carpenter kicks 71 yards from MIA 30 to OAK -1. J.Ford for 101 yards, TOUCHDOWN.',
#  'C.Barth kicks 72 yards from TB 30 to ATL -2. E.Weems for 102 yards, TOUCHDOWN. Tampa Bay challenged the runner was in bounds ruling, and the play was Upheld. (Timeout #2 at 10:03.)',
#  'J.Reed kicks 62 yards from SF 30 to SEA 8. L.Washington for 92 yards, TOUCHDOWN.',
#  'N.Rackers kicks 73 yards from HST 30 to BAL -3. D.Reed for 103 yards, TOUCHDOWN.',
#  'J.Scobee kicks onside 6 yards from JAC 35 to JAC 41. T.Hagler for 41 yards, TOUCHDOWN.',
#  'S.Suisham kicks 67 yards from PIT 30 to NYJ 3. B.Smith for 97 yards, TOUCHDOWN.',
#  'P.McAfee kicks 69 yards from IND 30 to OAK 1. J.Ford for 99 yards, TOUCHDOWN.',
#  'N.Kaeding kicks 67 yards from SD 30 to DEN 3. C.Vaughn for 97 yards, TOUCHDOWN.',
#  'T.Morstead kicks 73 yards from NO 35 to GB -8. R.Cobb for 108 yards, TOUCHDOWN.',
#  'N.Kaeding kicks 68 yards from SD 35 to MIN -3. P.Harvin for 103 yards, TOUCHDOWN.',
#  'S.Hauschka kicks 67 yards from SEA 35 to SF -2. T.Ginn for 102 yards, TOUCHDOWN.',
#  'B.Cundiff kicks 72 yards from BAL 35 to NYJ -7. J.McKnight for 107 yards, TOUCHDOWN.',
#  'P.Dawson kicks 66 yards from CLE 35 to OAK -1. J.Ford for 101 yards, TOUCHDOWN. The Replay Assistant challenged the runner was in bounds ruling, and the play was Upheld.',
#  'R.Longwell kicks 63 yards from MIN 35 to CHI 2. D.Hester for 98 yards, TOUCHDOWN.',
#  'J.Hanson kicks 66 yards from DET 35 to CAR -1. K.Pilares for 101 yards, TOUCHDOWN.',
#  'M.Koenen kicks 65 yards from TB 35 to TEN 0. M.Mariani to TEN 16 for 16 yards. Handoff to T.Campbell for 84 yards, TOUCHDOWN.',
#  'S.Janikowski kicks 70 yards from OAK 35 to SD -5. R.Goodman for 105 yards, TOUCHDOWN.',
#  'J.Hanson kicks 70 yards from DET 35 to TEN -5. D.Reynaud for 105 yards, TOUCHDOWN.',
#  'J.Hanson kicks 70 yards from DET 35 to MIN -5. P.Harvin for 105 yards, TOUCHDOWN.',
#  'S.Graham kicks 65 yards from HOU 35 to NYJ 0. J.McKnight for 100 yards, TOUCHDOWN.',
#  'D.Bailey kicks 73 yards from DAL 35 to BAL -8. J.Jones for 108 yards, TOUCHDOWN. Jacoby Jones ties NFL record for longest kickoff return. Jacoby Jones sets Ravens record with 108-KO return.',
#  'R.Bironas kicks 54 yards from TEN 35 to BUF 11. B.Smith for 89 yards, TOUCHDOWN.',
#  'N.Folk kicks 69 yards from NYJ 35 to NE -4. D.McCourty for 104 yards, TOUCHDOWN. 2nd longest KO return in franchise history (Hobbs 108)',
#  'M.Nugent kicks 70 yards from CIN 35 to DEN -5. T.Holliday for 105 yards, TOUCHDOWN.',
#  'S.Janikowski kicks 70 yards from OAK 35 to BAL -5. J.Jones for 105 yards, TOUCHDOWN. Jacoby Jones returns KO for touchdown to become first Raven to accomplish feat.',
#  'R.Lindell kicks 61 yards from BUF 35 to MIA 4. M.Thigpen for 96 yards, TOUCHDOWN.',
#  'S.Gostkowski kicks 70 yards from NE 35 to NYJ -5. J.McKnight to NYJ 20 for 25 yards (D.McCourty). FUMBLES (D.McCourty), RECOVERED by NE-J.Edelman at NYJ 22. J.Edelman for 22 yards, TOUCHDOWN.',
#  'D.Carpenter kicks 63 yards from MIA 35 to SEA 2. L.Washington for 98 yards, TOUCHDOWN.',
#  'T.Morstead kicks 62 yards from NO 35 to NYG 3. D.Wilson for 97 yards, TOUCHDOWN.',
#  'S.Graham kicks 66 yards from HOU 35 to IND -1. D.Karim for 101 yards, TOUCHDOWN.',
#  'S.Janikowski kicks 64 yards from OAK 35 to SD 1. M.Spurlock for 99 yards, TOUCHDOWN.',
#  'R.Gould kicks 70 yards from CHI 35 to MIN -5. C.Patterson for 105 yards, TOUCHDOWN.',
#  'A.Henery kicks 70 yards from PHI 35 to DEN -5. T.Holliday for 105 yards, TOUCHDOWN.',
#  'G.Zuerlein kicks 70 yards from STL 35 to HOU -5. K.Martin to HOU 10 for 15 yards (R.McLeod). FUMBLES (R.McLeod), RECOVERED by STL-D.Bates at HOU 11. D.Bates for 11 yards, TOUCHDOWN.',
#  'T.Masthay kicks 74 yards from GB 35 to MIN -9. C.Patterson for 109 yards, TOUCHDOWN.',
#  'S.Janikowski kicks 74 yards from OAK 35 to DAL -9. T.Williams to DAL 20 for 29 yards (K.Burnett). FUMBLES (K.Burnett), RECOVERED by OAK-G.Jenkins at DAL 23. G.Jenkins for 23 yards, TOUCHDOWN. The Replay Assistant challenged the fumble ruling, and the play was Upheld.',
#  'M.Prater kicks 73 yards from DEN 35 to KC -8. K.Davis for 108 yards, TOUCHDOWN.',
#  'K.Forbath kicks 60 yards from WAS 35 to KC 5. Q.Demps for 95 yards, TOUCHDOWN.',
#  'B.Walsh kicks 42 yards from MIN 35 to BAL 23. J.Jones for 77 yards, TOUCHDOWN. The Replay Assistant challenged the runner was in bounds ruling, and the play was Upheld.',
#  'A.Henery kicks 63 yards from PHI 35 to DET 2. J.Ross for 98 yards, TOUCHDOWN.',
#  'P.Dawson kicks 74 yards from SF 35 to TB -9. E.Page to TB 7 for 16 yards. FUMBLES, RECOVERED by SF-K.Hunter at TB 2. K.Hunter for 2 yards, TOUCHDOWN.',
#  'C.Sturgis kicks 67 yards from MIA 35 to BUF -2. C.Spiller for 102 yards, TOUCHDOWN. PENALTY on BUF, Unsportsmanlike Conduct, 15 yards, enforced between downs. Penalty for sideline interference.',
#  'T.Way kicks 67 yards from WAS 35 to PHI -2. C.Polk for 102 yards, TOUCHDOWN.',
#  'S.Gostkowski kicks 71 yards from NE 35 to CIN -6. B.Tate to CIN 11 for 17 yards (B.Bolden). FUMBLES (B.Bolden), RECOVERED by NE-K.Arrington at CIN 9. K.Arrington for 9 yards, TOUCHDOWN.',
#  'G.Zuerlein kicks 64 yards from STL 35 to KC 1. K.Davis for 99 yards, TOUCHDOWN.',
#  'S.Suisham kicks 73 yards from PIT 35 to BAL -8. J.Jones for 108 yards, TOUCHDOWN.',
#  'M.Crosby kicks 66 yards from GB 35 to CHI -1. C.Williams for 101 yards, TOUCHDOWN.',
#  'R.Succop kicks 72 yards from TEN 35 to PHI -7. J.Huff for 107 yards, TOUCHDOWN.',
#  'R.Gould kicks 73 yards from CHI 35 to ARI -8. D.Johnson for 108 yards, TOUCHDOWN.',
#  'J.Brown kicks 66 yards from NYG 35 to WAS -1. R.Ross for 101 yards, TOUCHDOWN.',
#  'R.Gould kicks 70 yards from CHI 35 to SEA -5. T.Lockett for 105 yards, TOUCHDOWN.',
#  'D.Bailey kicks 65 yards from DAL 35 to NYG 0. D.Harris for 100 yards, TOUCHDOWN.',
#  'J.Gay kicks 70 yards from BUF 35 to NYJ -5. D.Smith to NYJ 16 for 21 yards (B.Rambo). FUMBLES (B.Rambo), RECOVERED by BUF-Du.Williams at NYJ 19. Du.Williams for 19 yards, TOUCHDOWN.',
#  'S.Janikowski kicks 58 yards from OAK 35 to MIN 7. C.Patterson for 93 yards, TOUCHDOWN.',
#  'G.Gano kicks 64 yards from CAR 35 to WAS 1. A.Roberts for 99 yards, TOUCHDOWN.',
#  'S.Hauschka kicks 66 yards from SEA 35 to MIN -1. C.Patterson for 101 yards, TOUCHDOWN.',
#  'C.Santos kicks 61 yards from KC 35 to NYJ 4. J.Marshall to NYJ 23 for 19 yards (A.Sherman). FUMBLES (A.Sherman), RECOVERED by KC-D.Harris at NYJ 27. D.Harris for 27 yards, TOUCHDOWN.',
#  'D.Hopkins kicks 66 yards from WAS 20 to PHI 14. W.Smallwood for 86 yards, TOUCHDOWN.',
#  'B.Walsh kicks 63 yards from MIN 35 to PHI 2. J.Huff for 98 yards, TOUCHDOWN.',
#  'N.Folk kicks 66 yards from NYJ 30 to MIA 4. K.Drake for 96 yards, TOUCHDOWN.',
#  'M.Crosby kicks 64 yards from GB 35 to IND 1. J.Todman for 99 yards, TOUCHDOWN.',
#  'C.Catanzaro kicks 69 yards from ARI 35 to MIN -4. C.Patterson for 104 yards, TOUCHDOWN.',
#  'R.Dixon kicks 66 yards from DEN 20 to KC 14. T.Hill for 86 yards, TOUCHDOWN.',
#  'N.Novak kicks 65 yards from HOU 35 to JAX 0. M.Lee for 100 yards, TOUCHDOWN. PENALTY on JAX-M.Lee, Unsportsmanlike Conduct, 15 yards, enforced between downs.',
#  'C.Barth kicks 61 yards from CHI 35 to BAL 4. B.Rainey for 96 yards, TOUCHDOWN. The Replay Official reviewed the runner was not down by contact ruling, and the play was Upheld. The ruling on the field stands.',
#  'J.Myers kicks 68 yards from JAX 35 to LA -3. P.Cooper for 103 yards, TOUCHDOWN.',
#  'B.McManus kicks 68 yards from DEN 35 to NE -3. D.Lewis for 103 yards, TOUCHDOWN.',
#  'P.Murray kicks 40 yards from TB 35 to MIA 25. D.Williams to MIA 18 for -7 yards. Lateral to J.Landry to MIA 15 for -3 yards. FUMBLES, recovered by MIA-J.Grant at MIA 13. J.Grant to MIA 3 for -10 yards. FUMBLES, RECOVERED by TB-A.Glanton at MIA 0. TOUCHDOWN.',
#  'P.Murray kicks 68 yards from TB 35 to CAR -3. D.Byrd for 103 yards, TOUCHDOWN.',
#  'Z.Gonzalez kicks 61 yards from CLE 35 to PIT 4. J.Smith-Schuster for 96 yards, TOUCHDOWN.',
#  'P.Murray kicks 71 yards from TB 35 to NO -6. A.Kamara for 106 yards, TOUCHDOWN.',
#  'P.Dawson kicks 64 yards from ARI 35 to SEA 1. T.Lockett for 99 yards, TOUCHDOWN.',
#  'R.Succop kicks 67 yards from TEN 35 to MIA -2. J.Grant for 102 yards, TOUCHDOWN.',
#  'J.Sanders kicks 59 yards from MIA 35 to TEN 6. D.Jennings for 94 yards, TOUCHDOWN.',
#  'C.Parkey kicks 60 yards from CHI 35 to NE 5. C.Patterson for 95 yards, TOUCHDOWN.',
#  'S.Janikowski kicks 62 yards from SEA 35 to SF 3. R.James for 97 yards, TOUCHDOWN.',
#  'M.Crosby kicks 64 yards from GB 35 to NYJ 1. A.Roberts for 99 yards, TOUCHDOWN.',
#  'J.Elliott kicks 65 yards from PHI 35 to DET 0. J.Agnew for 100 yards, TOUCHDOWN.',
#  'J.Tucker kicks 57 yards from BAL 35 to CIN 8. B.Wilson for 92 yards, TOUCHDOWN.',
#  '(Onside Kick formation) J.Sanders kicks onside 10 yards from MIA 35 to MIA 45. M.Hyde for 45 yards, TOUCHDOWN.',
#  'W.Lutz kicks 67 yards from NO 35 to CHI -2. C.Patterson for 102 yards, TOUCHDOWN.',
#  'S.Hauschka kicks 66 yards from BUF 35 to MIA -1. J.Grant for 101 yards, TOUCHDOWN.',
#  'M.Prater kicks 59 yards from DET 35 to WAS 6. S.Sims MUFFS catch, and recovers at WAS 9. S.Sims for 91 yards, TOUCHDOWN.',
#  "Y.Koo kicks 34 yards from ATL 35 to SF 31. D.Samuel (didn't try to advance) to SF 15 for -16 yards. Lateral to R.James Jr. to SF 22 for 7 yards. Lateral to R.Mostert to SF 22 for no gain. FUMBLES, touched at SF 3, RECOVERED by ATL-O.Zaccheaus at SF 0. TOUCHDOWN.",
#  'T.Long kicks 69 yards from LAC 35 to KC -4. M.Hardman for 104 yards, TOUCHDOWN.']
